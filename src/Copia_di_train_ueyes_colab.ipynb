# %% [markdown]
# # Fine-tuning TempSAL su UEyes — Colab
#
# Notebook pronto per lanciare il training vero (Step 4) su GPU, invece che sulla CPU locale.
#
# **Prima di eseguire questo notebook**, su Google Drive crea una cartella (default atteso: `MyDrive/TempSAL_UEyes/`) contenente:
# - `multilevel_tempsal.pt` — il checkpoint pre-addestrato originale
# - `data_ueyes.zip` — l'archivio di `data_ueyes/` generato in locale (Step 1-2)
#
# Poi: **Runtime → Cambia tipo di runtime → GPU**, prima di eseguire le celle.

# %%
# Controllo che sia stata assegnata una GPU
# !nvidia-smi
# Out:
# Tue Sep  1 11:31:37 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Cambia questo path se hai usato un nome/percorso diverso su Drive
DRIVE_DIR = '/content/drive/MyDrive/TempSAL_UEyes'

assert os.path.isdir(DRIVE_DIR), (
    f"Cartella non trovata: {DRIVE_DIR}\n"
    "Creala su Drive e caricaci multilevel_tempsal.pt + data_ueyes.zip prima di continuare."
)
print('Contenuto trovato su Drive:', os.listdir(DRIVE_DIR))
# Out:
# Contenuto trovato su Drive: ['multilevel_tempsal.pt', 'data_ueyes.zip']

# %%
# Codice: sempre aggiornato da GitHub, non serve preparazione
# !git clone https://github.com/yuri-maradini/TempSal.git /content/TempSal
# Out:
# Cloning into '/content/TempSal'...
# remote: Enumerating objects: 188, done.
# remote: Counting objects: 100% (188/188), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 188 (delta 45), reused 179 (delta 36), pack-reused 0 (from 0)
# Receiving objects: 100% (188/188), 10.26 MiB | 14.92 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
import shutil

os.makedirs('/content/TempSal/src/checkpoints', exist_ok=True)
shutil.copy(
    f'{DRIVE_DIR}/multilevel_tempsal.pt',
    '/content/TempSal/src/checkpoints/multilevel_tempsal.pt',
)
print('Checkpoint copiato.')
# Out:
# Checkpoint copiato.

# %%
import time
import zipfile

# Estratto sul disco locale di Colab (veloce), non lasciato sul mount di Drive
# (l'I/O su Drive montato e' molto piu' lento per tanti file piccoli, e qui
# ce ne sono migliaia tra immagini, mappe e volumi temporali).
t0 = time.time()
with zipfile.ZipFile(f'{DRIVE_DIR}/data_ueyes.zip') as zf:
    zf.extractall('/content/TempSal/')
print(f'Dati estratti in {time.time() - t0:.0f}s')
# Out:
# Dati estratti in 38s

# %%
# Controllo veloce di integrita': i conteggi devono combaciare con quelli
# verificati in locale (1872 train / 108 val per ciascuna sottocartella)
for sub in ['images', 'maps', 'fixation_maps', 'saliency_volumes_5', 'fixation_volumes_5']:
    for split in ['train', 'val']:
        d = f'/content/TempSal/data_ueyes/{sub}/{split}'
        n = len(os.listdir(d)) if os.path.isdir(d) else 'MANCANTE'
        print(f'{sub:22s} {split:5s} -> {n}')
# Out:
# images                 train -> 1872
# images                 val   -> 108
# maps                   train -> 1872
# maps                   val   -> 108
# fixation_maps          train -> 1872
# fixation_maps          val   -> 108
# saliency_volumes_5     train -> 9360
# saliency_volumes_5     val   -> 540
# fixation_volumes_5     train -> 9360
# fixation_volumes_5     val   -> 540

# %%
# Colab ha gia' PyTorch con supporto CUDA preinstallato: installiamo solo le
# altre dipendenze del progetto, senza toccare torch/torchvision/torchaudio
# (forzare i pin usati in locale, pensati per una build CPU, rischierebbe di
# rimpiazzare la build CUDA gia' pronta di Colab con una incompatibile).
# !pip install -q wandb pycocotools ftfy einops clip-anytorch kornia regex
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 39.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 77.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 120.0 MB/s eta 0:00:00

# %%
# Verifica che l'installazione sopra non abbia rovinato il supporto CUDA di torch
import torch
print('torch', torch.__version__, '| CUDA disponibile:', torch.cuda.is_available())
assert torch.cuda.is_available(), 'GPU non disponibile: controlla Runtime > Cambia tipo di runtime > GPU'
# Out:
# torch 2.11.0+cu128 | CUDA disponibile: True

# %% [markdown]
# ## wandb (opzionale)
#
# Per il logging vero fai il login qui sotto (chiede l'API key, la trovi su wandb.ai/authorize). Se preferisci saltarlo, lascia questa cella non eseguita: la cella di training piu' sotto ha gia' `WANDB_MODE=disabled` di default.

# %%
# Facoltativa: esegui solo se vuoi il logging vero su wandb
# import wandb
# wandb.login()

# %% [markdown]
# ## Training
#
# Stessi flag della checklist in `TODO.md`. Punti da ricordare:
# - `--train_model 1` scongela la testa temporale di `pnas_vol`
# - `--train_enc 0` **deve** essere esplicito — il default e' `1`, pensato per l'altro tipo di modello, e sbloccherebbe per sbaglio l'intero backbone PNAS
# - `--model_val_path` punta a un file diverso da `multilevel_tempsal.pt`, cosi' l'originale resta intatto come riferimento
#
# Il checkpoint viene salvato **in locale** su Colab (piu' veloce, evita scritture lente/bloccanti sul mount di Drive durante il training); la cella successiva lo copia su Drive a fine training (o a intervalli, se la rilanci mentre il training e' ancora in corso).
#
# Consiglio: la prima volta prova con `--no_epochs 1` per verificare che tutto giri senza errori su questo ambiente, poi alza il numero di epoche per il training vero.

# %%
# %cd /content/TempSal/src
# !WANDB_MODE=disabled python train.py \
  --enc_model pnas_boosted_multi \
  --dataset_dir ../data_ueyes/ \
  --model_path ./checkpoints/multilevel_tempsal.pt \
  --model_vol_path ./checkpoints/multilevel_tempsal.pt \
  --train_model 1 \
  --train_enc 0 \
  --lr 1e-5 \
  --batch_size 32 \
  --no_epochs 10 \
  --model_val_path ./checkpoints/multilevel_tempsal_ueyes.pt
# Out:
# /content/TempSal/src
# PNAS Boosted Model PNASBoostedModelMultiLevel
# 96 96 54
# 96 270 108
# 270 540 216
# 540 1080 216
# 1080 1080 216
# 1080 1080 216
# 1080 1080 432
# 1080 2160 432
# 2160 2160 432
# 2160 2160 432
# 2160 2160 864
# 2160 4320 864
# 4320 4320 864
# 4320 4320 864
# 96 96 54
# 96 270 108
# 270 540 216
# 540 1080 216
# 1080 1080 216
# 1080 1080 216
# 1080 1080 432
# 1080 2160 432
# 2160 2160 432
# 2160 2160 432
# 2160 2160 864
# 2160 4320 864
# 4320 4320 864
# 4320 4320 864
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# cuda
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# [ 0, train] avg_loss : 0.61666
# 100% 4/4 [00:09<00:00,  2.46s/it]
# [ 0,   val] CC : 0.65493, KLDIV : 0.50532, NSS : 1.16202, SIM : 0.62246  time:0.164169 minutes
# [ 0,   val] Vol CC : 0.47879, Vol KLDIV : 1.11505
# [ 0,  save, ./checkpoints/multilevel_tempsal_ueyes.pt]
#
# [ 1, train] avg_loss : 0.16573
# 100% 4/4 [00:10<00:00,  2.64s/it]
# [ 1,   val] CC : 0.68585, KLDIV : 0.47041, NSS : 1.20698, SIM : 0.64101  time:0.175759 minutes
# [ 1,   val] Vol CC : 0.53286, Vol KLDIV : 1.01029
# [ 1,  save, ./checkpoints/multilevel_tempsal_ueyes.pt]
#
# [ 2, train] avg_loss : 0.03161
# 100% 4/4 [00:11<00:00,  3.00s/it]
# [ 2,   val] CC : 0.69778, KLDIV : 0.45563, NSS : 1.22195, SIM : 0.64977  time:0.199753 minutes
# [ 2,   val] Vol CC : 0.55914, Vol KLDIV : 0.95988
# [ 2,  save, ./checkpoints/multilevel_tempsal_ueyes.pt]
#
# [ 3, train] avg_loss : -0.04696
# 100% 4/4 [00:12<00:00,  3.01s/it]
# [ 3,   val] CC : 0.70734, KLDIV : 0.44445, NSS : 1.23108, SIM : 0.65525  time:0.200697 minutes
# [ 3,   val] Vol CC : 0.57489, Vol KLDIV : 0.92810
# [ 3,  save, ./checkpoints/multilevel_tempsal_ueyes.pt]
#
# [ 4, train] avg_loss : -0.10352
# 100% 4/4 [00:10<00:00,  2.71s/it]
# [ 4,   val] CC : 0.71296, KLDIV : 0.43716, NSS : 1.24220, SIM : 0.65801  time:0.180987 minutes
# [ 4,   val] Vol CC : 0.58829, Vol KLDIV : 0.90099
# [ 4,  save, ./checkpoints/multilevel_tempsal_ueyes.pt]
#
# [ 5, train] avg_loss : -0.15369
# 100% 4/4 [00:10<00:00,  2.54s/it]
# [ 5,   val] CC : 0.71969, KLDIV : 0.43005, NSS : 1.25636, SIM : 0.66270  time:0.169256 minutes
# [ 5,   val] Vol CC : 0.59656, Vol KLDIV : 0.88492
# [ 5,  save, ./checkpoints/multilevel_tempsal_ueyes.pt]
#
# [ 6, train] avg_loss : -0.19564
# 100% 4/4 [00:10<00:00,  2.66s/it]
# [ 6,   val] CC : 0.71737, KLDIV : 0.43264, NSS : 1.23638, SIM : 0.65714  time:0.177328 minutes
# [ 6,   val] Vol CC : 0.60561, Vol KLDIV : 0.86137
#
# [ 7, train] avg_loss : -0.23738
# 100% 4/4 [00:10<00:00,  2.62s/it]
# [ 7,   val] CC : 0.72468, KLDIV : 0.42313, NSS : 1.28517, SIM : 0.66524  time:0.174437 minutes
# [ 7,   val] Vol CC : 0.61327, Vol KLDIV : 0.83861
# [ 7,  save, ./checkpoints/multilevel_tempsal_ueyes.pt]
#
# [ 8, train] avg_loss : -0.27410
# 100% 4/4 [00:11<00:00,  2.84s/it]
# [ 8,   val] CC : 0.72367, KLDIV : 0.42344, NSS : 1.25730, SIM : 0.66474  time:0.189073 minutes
# [ 8,   val] Vol CC : 0.61737, Vol KLDIV : 0.82896
#
# [ 9, train] avg_loss : -0.30690
# 100% 4/4 [00:10<00:00,  2.58s/it]
# [ 9,   val] CC : 0.72193, KLDIV : 0.42553, NSS : 1.23885, SIM : 0.66289  time:0.172194 minutes
# [ 9,   val] Vol CC : 0.62085, Vol KLDIV : 0.82654

# %%
# Copia il checkpoint fine-tuned su Drive, cosi' sopravvive alla chiusura
# della sessione Colab. Puoi rieseguire questa cella anche a training ancora
# in corso, per avere un backup intermedio.
import shutil

src_ckpt = '/content/TempSal/src/checkpoints/multilevel_tempsal_ueyes.pt'
dst_ckpt = f'{DRIVE_DIR}/multilevel_tempsal_ueyes.pt'
shutil.copy(src_ckpt, dst_ckpt)
print('Copiato su Drive:', dst_ckpt)
# Out:
# Copiato su Drive: /content/drive/MyDrive/TempSAL_UEyes/multilevel_tempsal_ueyes.pt
