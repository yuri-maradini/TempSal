# %% [markdown]
# # TempSAL Inference Notebook — Fine-tuned (UEyes, v4)
#
# Copia di `inference.ipynb` pre-configurata per usare `multilevel_tempsal_ueyes_v4.pt` (il checkpoint fine-tuned su UEyes) invece del checkpoint originale — utile per confrontare rapidamente baseline vs fine-tuned sulla stessa immagine, aprendo i due notebook fianco a fianco.

# %% [markdown]
# This notebook includes the code to load and test the TempSAL model.
# Download the checkpoints from :
# https://drive.google.com/drive/folders/1W92oXYra_OPYkR1W56D80iDexWIR7f7Z?usp=sharing<br>
# Place them under the "checkpoints" folder. The folder structure should be as follows:
#
# src
# >  inference.ipynb <br>
# >  checkpoints<br>
# >  testing<br>
# > > images<br>
# > > predictions<br>
# > > gt<br>

# %%
# Import packages
import torch
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from collections import OrderedDict
import torch.nn as nn
from torchvision.utils import save_image

def to_np(tensor):
    return tensor.permute( 1, 2, 0).detach().cpu().numpy()


def plot_side_by_side(img_array, names=[], colormap = "gray"):
# Create a figure and display the image
    num_imgs = len(img_array)
    plt.subplots(1,num_imgs, figsize=(15,5))
    for i in range(1,num_imgs+1):
        plt.subplot(1,num_imgs,i)
        #plt.imshow(img_array[i-1].cpu().squeeze(0).permute(1,2,0).detach().numpy())
        plt.imshow(img_array[i-1], cmap=colormap)
        if len(names)>0:
            plt.title(str(names[i-1]))
    # Show the figure
    plt.show()
    
# Transformations for the input images
img_transform = transforms.Compose([
            transforms.Resize((256, 256)),
            transforms.ToTensor(),
            transforms.Normalize([0.5, 0.5, 0.5],
                                [0.5, 0.5, 0.5])
        ])
gt_transform = transforms.Compose([
            transforms.Resize((256, 256)),
            transforms.ToTensor(),
            #transforms.Normalize([0.5],[0.5])
        ])

# Functions to load images
def get_image(img_path):
    img = Image.open(img_path).convert('RGB')
    img = img_transform(img)
    return img

def get_image_nonorm(img_path):
    img = Image.open(img_path).convert('RGB')
    img = gt_transform(img)
    return img

def get_gt_tensor(img_path):
    img = Image.open(img_path).convert('L')
    img = gt_transform(img)

    return img
                
def load_model(model_checkpoint_path):
    state_dict = torch.load(model_checkpoint_path)
    new_state_dict = OrderedDict()

    for k, v in state_dict.items():
        if 'module' not in k.split('.')[0]:
            k = 'module.' + k
        else:
            k = k.replace('features.module.', 'module.features.')
        new_state_dict[k] = v
    #     print(k)
    model = nn.DataParallel(model)
    model.load_state_dict(new_state_dict)
    return model
    
# Predict saliency
def predict(image):

    with torch.no_grad():
        fin_pred , temp_pred = model(image) #Image saliency and temporal saliency predictions
        temp_pred = temp_pred.squeeze(0)

    return fin_pred , temp_pred

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Paths to the model checkpoints
# Fine-tuned su UEyes (Step 4.6, TODO.md) -- il checkpoint migliore sul ramo
# temporale. Per il confronto, il checkpoint originale (SALICON) e' caricato
# in inference.ipynb.
model_checkpoint_path = "./checkpoints/multilevel_tempsal_ueyes_v4.pt"
time_slices = 5
train_model = 0

from model import PNASBoostedModelMultiLevel
model = PNASBoostedModelMultiLevel(device, model_checkpoint_path, model_checkpoint_path, time_slices, train_model=train_model )    
    
# Load model    
#model = load_model(model_checkpoint_path)
model = model.to(device)
model.eval()
# Out:
# 96 96 54
# 96 270 108
# 270 540 216
# 540 1080 216
# 1080 1080 216
# 1080 1080 216
# 1080 1080 432
# 1080 2160 432
# 2160 2160 432
# 2160 2160 432
# 2160 2160 864
# 2160 4320 864
# 4320 4320 864
# 4320 4320 864
# 96 96 54
# 96 270 108
# 270 540 216
# 540 1080 216
# 1080 1080 216
# 1080 1080 216
# 1080 1080 432
# 1080 2160 432
# 2160 2160 432
# 2160 2160 432
# 2160 2160 864
# 2160 4320 864
# 4320 4320 864
# 4320 4320 864
# PNASBoostedModelMultiLevel(
#   (linear_upsampling): UpsamplingBilinear2d(scale_factor=2.0, mode='bilinear')
#   (deconv_layer1): Sequential(
#     (0): Conv2d(2678, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): UpsamplingBilinear2d(scale_factor=2.0, mode='bilinear')
#   )
#   (deconv_layer2): Sequential(
#     (0): Conv2d(1342, 270, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): UpsamplingBilinear2d(scale_factor=2.0, mode='bilinear')
#   )
#   (deconv_layer3): Sequential(
#     (0): Conv2d(546, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): UpsamplingBilinear2d(scale_factor=2.0, mode='bilinear')
#   )
#   (deconv_layer4): Sequential(
#     (0): Conv2d(198, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): UpsamplingBilinear2d(scale_factor=2.0, mode='bilinear')
#   )
#   (deconv_mix): Sequential(
#     (0): Conv2d(134, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): Conv2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): Sigmoid()
#   )
#   (pnas_vol): DataParallel(
#     (module): DataParallel(
#       (module): PNASVolModellast(
#         (pnas): NetworkImageNet(
#           (conv0): Conv2d(3, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#           (conv0_bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#           (stem1): Cell(
#             (preprocess0): Identity()
#             (preprocess1): ReLUConvBN(
#               (op): Sequential(
#                 (0): ReLU()
#                 (1): Conv2d(96, 54, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (2): BatchNorm2d(54, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#               )
#             )
#             (_ops): ModuleList(
#               (0): SepConv(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(96, 96, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=96, bias=False)
#                   (2): Conv2d(96, 54, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (3): BatchNorm2d(54, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   (4): ReLU()
#                   (5): Conv2d(54, 54, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=54, bias=False)
#                   (6): Conv2d(54, 54, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (7): BatchNorm2d(54, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (1): Sequential(
#                 (0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#                 (1): Conv2d(96, 54, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (2): BatchNorm2d(54, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#               )
#               (2): SepConv(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(54, 54, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=54, bias=False)
#                   (2): Conv2d(54, 54, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (3): BatchNorm2d(54, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   (4): ReLU()
#                   (5): Conv2d(54, 54, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=54, bias=False)
#                   (6): Conv2d(54, 54, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (7): BatchNorm2d(54, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#               (4): SepConv(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(54, 54, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=54, bias=False)
#                   (2): Conv2d(54, 54, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (3): BatchNorm2d(54, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   (4): ReLU()
#                   (5): Conv2d(54, 54, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=54, bias=False)
#                   (6): Conv2d(54, 54, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (7): BatchNorm2d(54, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (5): SepConv(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(54, 54, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=54, bias=False)
#                   (2): Conv2d(54, 54, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (3): BatchNorm2d(54, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   (4): ReLU()
#                   (5): Conv2d(54, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=54, bias=False)
#                   (6): Conv2d(54, 54, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (7): BatchNorm2d(54, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (6): SepConv(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(54, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=54, bias=False)
#                   (2): Conv2d(54, 54, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (3): BatchNorm2d(54, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   (4): ReLU()
#                   (5): Conv2d(54, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=54, bias=False)
#                   (6): Conv2d(54, 54, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (7): BatchNorm2d(54, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (7): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#               (8): SepConv(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#                   (2): Conv2d(96, 54, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (3): BatchNorm2d(54, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   (4): ReLU()
#                   (5): Conv2d(54, 54, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=54, bias=False)
#                   (6): Conv2d(54, 54, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (7): BatchNorm2d(54, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (9): ReLUConvBN(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(54, 54, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                   (2): BatchNorm2d(54, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#             )
#           )
#           (stem2): Cell(
#             (preprocess0): FactorizedReduce(
#               (relu): ReLU()
#               (conv_1): Conv2d(96, 54, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (conv_2): Conv2d(96, 54, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (bn): BatchNorm2d(108, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#               (pad): ConstantPad2d(padding=(0, 1, 0, 1), value=0)
#             )
#             (preprocess1): ReLUConvBN(
#               (op): Sequential(
#                 (0): ReLU()
#                 (1): Conv2d(270, 108, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (2): BatchNorm2d(108, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#               )
#             )
#             (_ops): ModuleList(
#               (0): SepConv(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(108, 108, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=108, bias=False)
#                   (2): Conv2d(108, 108, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (3): BatchNorm2d(108, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   (4): ReLU()
#                   (5): Conv2d(108, 108, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=108, bias=False)
#                   (6): Conv2d(108, 108, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (7): BatchNorm2d(108, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (1): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#               (2): SepConv(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(108, 108, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=108, bias=False)
#                   (2): Conv2d(108, 108, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (3): BatchNorm2d(108, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   (4): ReLU()
#                   (5): Conv2d(108, 108, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=108, bias=False)
#                   (6): Conv2d(108, 108, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (7): BatchNorm2d(108, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#               (4): SepConv(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(108, 108, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=108, bias=False)
#                   (2): Conv2d(108, 108, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (3): BatchNorm2d(108, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   (4): ReLU()
#                   (5): Conv2d(108, 108, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=108, bias=False)
#                   (6): Conv2d(108, 108, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (7): BatchNorm2d(108, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (5): SepConv(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(108, 108, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=108, bias=False)
#                   (2): Conv2d(108, 108, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (3): BatchNorm2d(108, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   (4): ReLU()
#                   (5): Conv2d(108, 108, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=108, bias=False)
#                   (6): Conv2d(108, 108, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (7): BatchNorm2d(108, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (6): SepConv(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(108, 108, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=108, bias=False)
#                   (2): Conv2d(108, 108, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (3): BatchNorm2d(108, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   (4): ReLU()
#                   (5): Conv2d(108, 108, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=108, bias=False)
#                   (6): Conv2d(108, 108, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (7): BatchNorm2d(108, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (7): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#               (8): SepConv(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(108, 108, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=108, bias=False)
#                   (2): Conv2d(108, 108, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (3): BatchNorm2d(108, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   (4): ReLU()
#                   (5): Conv2d(108, 108, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=108, bias=False)
#                   (6): Conv2d(108, 108, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (7): BatchNorm2d(108, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (9): ReLUConvBN(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(108, 108, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                   (2): BatchNorm2d(108, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#             )
#           )
#           (cells): ModuleList(
#             (0): Cell(
#               (preprocess0): FactorizedReduce(
#                 (relu): ReLU()
#                 (conv_1): Conv2d(270, 108, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (conv_2): Conv2d(270, 108, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (bn): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 (pad): ConstantPad2d(padding=(0, 1, 0, 1), value=0)
#               )
#               (preprocess1): ReLUConvBN(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(540, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (2): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (_ops): ModuleList(
#                 (0): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(216, 216, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=216, bias=False)
#                     (2): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(216, 216, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=216, bias=False)
#                     (6): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (2): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(216, 216, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=216, bias=False)
#                     (2): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(216, 216, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=216, bias=False)
#                     (6): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (3): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (4): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(216, 216, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=216, bias=False)
#                     (2): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(216, 216, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=216, bias=False)
#                     (6): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (5-6): 2 x SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#                     (2): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#                     (6): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (7): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (8): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#                     (2): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#                     (6): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (9): Identity()
#               )
#             )
#             (1): Cell(
#               (preprocess0): ReLUConvBN(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(540, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (2): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (preprocess1): ReLUConvBN(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(1080, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (2): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (_ops): ModuleList(
#                 (0): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(216, 216, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=216, bias=False)
#                     (2): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(216, 216, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=216, bias=False)
#                     (6): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (2): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(216, 216, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=216, bias=False)
#                     (2): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(216, 216, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=216, bias=False)
#                     (6): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (3): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (4): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(216, 216, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=216, bias=False)
#                     (2): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(216, 216, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=216, bias=False)
#                     (6): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (5-6): 2 x SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#                     (2): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#                     (6): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (7): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (8): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#                     (2): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#                     (6): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (9): Identity()
#               )
#             )
#             (2-3): 2 x Cell(
#               (preprocess0): ReLUConvBN(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(1080, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (2): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (preprocess1): ReLUConvBN(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(1080, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (2): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (_ops): ModuleList(
#                 (0): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(216, 216, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=216, bias=False)
#                     (2): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(216, 216, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=216, bias=False)
#                     (6): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (2): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(216, 216, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=216, bias=False)
#                     (2): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(216, 216, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=216, bias=False)
#                     (6): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (3): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (4): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(216, 216, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=216, bias=False)
#                     (2): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(216, 216, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=216, bias=False)
#                     (6): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (5-6): 2 x SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#                     (2): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#                     (6): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (7): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (8): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#                     (2): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=216, bias=False)
#                     (6): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(216, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (9): Identity()
#               )
#             )
#             (4): Cell(
#               (preprocess0): ReLUConvBN(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(1080, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (2): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (preprocess1): ReLUConvBN(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(1080, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (2): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (_ops): ModuleList(
#                 (0): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(432, 432, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=432, bias=False)
#                     (2): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#                     (6): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (1): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#                 (2): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(432, 432, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), groups=432, bias=False)
#                     (2): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(432, 432, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=432, bias=False)
#                     (6): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#                 (4): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(432, 432, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=432, bias=False)
#                     (2): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#                     (6): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (5): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(432, 432, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=432, bias=False)
#                     (2): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#                     (6): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (6): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#                     (2): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#                     (6): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (7): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#                 (8): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(432, 432, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=432, bias=False)
#                     (2): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#                     (6): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (9): ReLUConvBN(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(432, 432, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                     (2): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#               )
#             )
#             (5): Cell(
#               (preprocess0): FactorizedReduce(
#                 (relu): ReLU()
#                 (conv_1): Conv2d(1080, 216, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (conv_2): Conv2d(1080, 216, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (bn): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 (pad): ConstantPad2d(padding=(0, 1, 0, 1), value=0)
#               )
#               (preprocess1): ReLUConvBN(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(2160, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (2): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (_ops): ModuleList(
#                 (0): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#                     (2): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#                     (6): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (2): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(432, 432, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=432, bias=False)
#                     (2): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(432, 432, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=432, bias=False)
#                     (6): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (3): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (4): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#                     (2): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#                     (6): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (5-6): 2 x SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#                     (2): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#                     (6): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (7): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (8): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#                     (2): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#                     (6): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (9): Identity()
#               )
#             )
#             (6-7): 2 x Cell(
#               (preprocess0): ReLUConvBN(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(2160, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (2): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (preprocess1): ReLUConvBN(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(2160, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (2): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (_ops): ModuleList(
#                 (0): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#                     (2): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#                     (6): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (2): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(432, 432, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=432, bias=False)
#                     (2): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(432, 432, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=432, bias=False)
#                     (6): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (3): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (4): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#                     (2): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#                     (6): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (5-6): 2 x SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#                     (2): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#                     (6): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (7): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (8): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#                     (2): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(432, 432, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=432, bias=False)
#                     (6): Conv2d(432, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(432, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (9): Identity()
#               )
#             )
#             (8): Cell(
#               (preprocess0): ReLUConvBN(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(2160, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (2): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (preprocess1): ReLUConvBN(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(2160, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (2): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (_ops): ModuleList(
#                 (0): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(864, 864, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=864, bias=False)
#                     (2): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(864, 864, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=864, bias=False)
#                     (6): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...
#                 (4): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(864, 864, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=864, bias=False)
#                     (2): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(864, 864, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=864, bias=False)
#                     (6): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (5): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(864, 864, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=864, bias=False)
#                     (2): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#                     (6): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (6): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#                     (2): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#                     (6): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (7): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#                 (8): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(864, 864, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=864, bias=False)
#                     (2): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#                     (6): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (9): ReLUConvBN(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(864, 864, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                     (2): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#               )
#             )
#             (9): Cell(
#               (preprocess0): FactorizedReduce(
#                 (relu): ReLU()
#                 (conv_1): Conv2d(2160, 432, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (conv_2): Conv2d(2160, 432, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (bn): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 (pad): ConstantPad2d(padding=(0, 1, 0, 1), value=0)
#               )
#               (preprocess1): ReLUConvBN(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(4320, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (2): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (_ops): ModuleList(
#                 (0): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(864, 864, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=864, bias=False)
#                     (2): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(864, 864, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=864, bias=False)
#                     (6): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (2): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(864, 864, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=864, bias=False)
#                     (2): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(864, 864, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=864, bias=False)
#                     (6): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (3): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (4): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(864, 864, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=864, bias=False)
#                     (2): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(864, 864, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=864, bias=False)
#                     (6): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (5-6): 2 x SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#                     (2): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#                     (6): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (7): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (8): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#                     (2): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#                     (6): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (9): Identity()
#               )
#             )
#             (10-11): 2 x Cell(
#               (preprocess0): ReLUConvBN(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(4320, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (2): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (preprocess1): ReLUConvBN(
#                 (op): Sequential(
#                   (0): ReLU()
#                   (1): Conv2d(4320, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (2): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                 )
#               )
#               (_ops): ModuleList(
#                 (0): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(864, 864, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=864, bias=False)
#                     (2): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(864, 864, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=864, bias=False)
#                     (6): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (2): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(864, 864, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=864, bias=False)
#                     (2): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(864, 864, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=864, bias=False)
#                     (6): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (3): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (4): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(864, 864, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=864, bias=False)
#                     (2): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(864, 864, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=864, bias=False)
#                     (6): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (5-6): 2 x SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#                     (2): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#                     (6): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (7): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#                 (8): SepConv(
#                   (op): Sequential(
#                     (0): ReLU()
#                     (1): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#                     (2): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (3): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                     (4): ReLU()
#                     (5): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#                     (6): Conv2d(864, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                     (7): BatchNorm2d(864, eps=0.001, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#                   )
#                 )
#                 (9): Identity()
#               )
#             )
#           )
#           (relu): ReLU()
#           (global_pooling): AdaptiveAvgPool2d(output_size=1)
#           (classifier): Linear(in_features=4320, out_features=1001, bias=True)
#         )
#         (padding): ConstantPad2d(padding=(0, 1, 0, 1), value=0)
#         (linear_upsampling): UpsamplingBilinear2d(scale_factor=2.0, mode='bilinear')
#         (deconv_layer0): Sequential(
#           (0): Conv2d(4320, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#           (2): UpsamplingBilinear2d(scale_factor=2.0, mode='bilinear')
#         )
#         (deconv_layer1): Sequential(
#           (0): Conv2d(2672, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#           (2): UpsamplingBilinear2d(scale_factor=2.0, mode='bilinear')
#         )
#         (deconv_layer2): Sequential(
#           (0): Conv2d(1336, 270, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#           (2): UpsamplingBilinear2d(scale_factor=2.0, mode='bilinear')
#         )
#         (deconv_layer3): Sequential(
#           (0): Conv2d(540, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#           (2): UpsamplingBilinear2d(scale_factor=2.0, mode='bilinear')
#         )
#         (deconv_layer4): Sequential(
#           (0): Conv2d(192, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#           (2): UpsamplingBilinear2d(scale_factor=2.0, mode='bilinear')
#         )
#         (deconv_layer5): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#           (2): Conv2d(128, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (3): Sigmoid()
#         )
#       )
#     )
#   )
# )

# %%
# Provide the paths to the images you want to test
image_name = "COCO_val2014_000000000208"
image_paths = ["./testing/images/"+image_name+ ".jpg"]
gt_paths = ["./testing/gt/"+image_name+ ".png"]
gt_vol_paths = ["./testing/gt/"+image_name+ "_0.png","./testing/gt/"+image_name+ "_1.png","./testing/gt/"+image_name+ "_2.png","./testing/gt/"+image_name+ "_3.png","./testing/gt/"+image_name+ "_4.png" ]

# %%
# A prediction with ground truth from SALICON validation dataset
# Loop over the images, make predictions, and display the results
for image_path in image_paths:
    # Read image
    image = get_image(image_path)
    # Predict saliency
    fin_pred , temp_pred  = predict(image.unsqueeze(0))
    temp_pred = temp_pred.unsqueeze(1)
    
    # Display the image and prediction
    #plt.axis("off")
    plot_side_by_side([to_np(get_gt_tensor(gt_vol_paths[0])),to_np(get_gt_tensor(gt_vol_paths[1])),to_np(get_gt_tensor(gt_vol_paths[2])),to_np(get_gt_tensor(gt_vol_paths[3])), to_np(get_gt_tensor(gt_vol_paths[4]))  ], names=["0-1 s Ground Truth", "1-2 s Ground Truth","2-3 s Ground Truth","3-4 s Ground Truth","4-5 s Ground Truth"  ], colormap="hot")    
    plot_side_by_side([to_np(temp_pred[0]),to_np(temp_pred[1]),to_np(temp_pred[2]),to_np(temp_pred[3]),to_np(temp_pred[4]) ], names=["0-1 s Prediction", "1-2 s Prediction","2-3 s Prediction","3-4 s Prediction","4-5 s Prediction" ], colormap="hot")
    plot_side_by_side([to_np(get_image_nonorm(image_path)), to_np(get_gt_tensor(gt_paths[0])), to_np(fin_pred)], names=["Input image", "0-5 s Ground Truth","0-5 s Prediction"], colormap="gray")

    plt.show()

# %%
# Save predictions
for idx,p in enumerate(temp_pred):
    save_image(p, './testing/predictions/temporal_saliency_prediction_slice_'+str(idx)+'.png',normalize=True)
save_image(fin_pred, './testing/predictions/image_saliency_prediction.png',normalize=True)

# %%
# Test your own images
# Metti qui il file da testare (es. lo screenshot della home page dell'universita').
# Stesso path in inference.ipynb, cosi' puoi confrontare i due modelli sulla
# stessa immagine senza dover modificare due volte il notebook.
image_paths = ["./testing/images/unipd.png"]

# %%
# Loop over the images, make predictions, and display the results
for image_path in image_paths:
    # Read image
    image = get_image(image_path)
    # Predict saliency
    fin_pred , pred_vol  = predict(image.unsqueeze(0))
    pred_vol = pred_vol.unsqueeze(1)

    # Display the image and prediction
    plot_side_by_side([to_np(pred_vol[0]),to_np(pred_vol[1]),to_np(pred_vol[2]),to_np(pred_vol[3]),to_np(pred_vol[4]) ], names=["0-1 s Prediction", "1-2 s Prediction","2-3 s Prediction","3-4 s Prediction","4-5 s Prediction" ], colormap="hot")
    plot_side_by_side([ to_np(get_image_nonorm(image_path)), to_np(fin_pred)], names=["Input image","0-5 s Prediction"], colormap="gray")
    plt.show()
